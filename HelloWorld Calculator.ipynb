# %%
import sympy as smp
from sympy import *
from sympy.plotting import plot3d

active = True

x, y, z = smp.symbols("x y z")
 
while (active):
    print("Welcome to this Python graphing calculator! This program can take in both single and multi-variable (up to 3 variables supported) functions and perform calculus operations on them in addition to graphing them.")
    print("")
    print("Please adhere to this syntax when entering functions: ") # displays information on how to enter functions
    print("Use ** for exponents.")
    print("Use 'pi' to access the constant π.")
    print("Use 'E' (case sensitive) to access the natural number e.")
    print("Use 'oo' to indicate infinity.")
    print("Square root function ---> sqrt(x)") # sqrt function
    print("Nth root function ---> root(x,n)") # nth root function
    print("sin(x) ---> sin(x)") # sin function
    print("cos(x) ---> cos(x)") # cos function
    print("tan(x) ---> tan(x)") # tan function
    print("csc(x) ---> csc(x)") # csc function
    print("sec(x) ---> sec(x)") # sec function
    print("cot(x) ---> cot(x)") # cot function
    print("sinc(x) ---> sinc(x)") # sinc function
    print("sin inverse ---> asin(x)") # inverse sin
    print("cos inverse ---> acos(x)") # inverse cos
    print("tan inverse ---> atan(x)") # inverse tan
    print("csc inverse ---> acsc(x)") # inverse csc
    print("sec inverse ---> asec(x)") # inverse sec
    print("cotan inverse ---> acot(x)") # inverse tan
    print("sinh(x) ---> sinh(x)") # sinh
    print("cosh(x) ---> cosh(x)") # cosh
    print("tanh(x) ---> tanh(x)") # tanh
    print("csch(x) ---> csch(x)") # csch
    print("sech(x) ---> sech(x)") # sech
    print("coth(x) ---> coth(x)") # tanh
    print("arcsinh(x) ---> asinh(x)") # inverse sinh
    print("arccosh(x) ---> acosh(x)") # inverse cosh
    print("arctanh(x) ---> atanh(x)") # inverse tanh
    print("csch inverse ---> acsch(x)") # inverse csch
    print("sech inverse ---> asech(x)") # inverse sech
    print("coth inverse ---> acoth(x)") # inverse coth
    print("log(x) ---> log(x, base)") # log functions
    print("e^x --> exp(x)") # e^x function
    print("|x| ---> Abs(x)") # absolute value function
    print("")

    function_type = input("Are you working with a single or multivariable function? Enter 's' for single variable and 'm' for multivariable.")
    if (function_type != "s" and function_type != "m"):
        print("Invalid input. Please try again")
        break
    elif (function_type == "s"):
        f = input("Please enter a single-variable function using x as the independent variable (NOTE: Avoid including other unknown variables in the function. Doing so will cause the program to crash or produce meaningless outputs.): ")
        y = smp.sympify(f)
        response1 = input("Do you want to evaluate this function at a point? Enter y for 'Yes' and any other key for 'no.' ")

        if (response1 == "y"):
            point = smp.sympify(input("Enter a point to evaluate the function at: "))
            evaluated_function = y.subs({'x':point}).evalf()
            print("The value of " + f + " at x = " + str(point) + " is" + " " + str(evaluated_function) + ".")
       
        response2 = input("Do you want to graph this function? Enter y for 'Yes' and any other key for 'no.' ")

        if (response2 == "y"):
            lower_x = smp.sympify(input("Please enter a lower bound for x: "))
            upper_x = smp.sympify(input("Please enter an upper bound for x: "))
            smp.plot(y, (x,lower_x,upper_x), title = 'Graph of f(x)', show=true)

        response3 = input("Do you want to find the derivative of this function? Enter y for 'Yes' and any other key for 'no.' ")

        if (response3 == "y"):
            derivative = smp.diff(y,x)
            print("The derivative of " + str(y) + " is " + str(derivative) + ".")


        response4 = input("Do you want to graph the derivative of this function? Enter y for 'Yes' and any other key for 'no.' ")

        if (response4 == "y"):
            derivative = smp.diff(y,x)
            lower_x = smp.sympify(input("Please enter a lower bound for x: "))
            upper_x = smp.sympify(input("Please enter an upper bound for x: "))
            smp.plot(derivative, (x,lower_x,upper_x), title = 'Graph of derivative of f(x)', show=true)


        response5 = input("Do you want to evaluate this derivative at a point? Enter y for 'Yes' and any other key for 'no.' ")

        if (response5 == "y"):
            derivative = smp.diff(y,x)
            point = smp.sympify(input("Enter a point to evaluate the derivative at: "))
            print("The derivative of " + str(y) + " at x = " + str(point) + " is " + str(derivative.subs({'x':point}).evalf()) + ".")

        response6 = input("Do you want to find the antiderivative (integral) of this function? Enter y for 'Yes' and any other key for 'no.' ")

        if (response6 == "y"):
            indefinite_integral = smp.integrate(y,x)
            print("The indefinite integral of " + str(y) + " is " + str(indefinite_integral) + " + C.") 

        response7 = input("Do you want to graph the antiderivative of this function? Enter y for 'Yes' and any other key for 'no.' ")

        if (response7 == "y"):
            indefinite_integral = smp.integrate(y,x)
            lower_x = smp.sympify(input("Please enter a lower bound for x: "))
            upper_x = smp.sympify(input("Please enter an upper bound for x: "))
            smp.plot(indefinite_integral, (x,lower_x,upper_x), title = 'Graph of F(x)', show=true)

        response8 = input("Do you want to evaluate a definite integral of this function of over an interval? Enter y for 'Yes' and any other key for 'no.' ")

        if (response8 == "y"):
            lower_x = smp.sympify(input("Enter the lower bound of integration: "))
            upper_x = smp.sympify(input("Enter the upper bound of integration: "))
            definite_integral = smp.integrate(y, (x, lower_x, upper_x))
            print("The definite integral of " + str(y) + " from x = " + str(lower_x) + " x = " + str(upper_x) + " is " + str(definite_integral) + ".")

        print("")
        use_again = input("Calculations completed. Would you like to use the calculator again? Enter y for 'Yes' and any other key for 'no.' ")
        if (use_again == "y"):
            print("")
            continue
        else:
            print("")
            print("Thank you for using the calculator!")
            break
            
    elif (function_type == "m"):
        variable_num = int(input("Enter the amount of variables present (Enter 2 for 2 variables and 3 for three variables): "))
        if (variable_num != 2 and variable_num != 3):
            print("Invalid response. Please try again.")
            break
        elif (variable_num == 2):
            f = input("Please enter a function of (x,y) (NOTE: Avoid including other unknown variables in the function. Doing so will cause the program to crash or produce meaningless outputs.): ")
            m = smp.sympify(f)
            response1 = input("Do you want to evaluate this function at a point? Enter y for 'Yes' and any other key for 'no.' ")

            if (response1 == "y"):
                x_point = smp.sympify(input("Enter the x-coordinate: "))
                y_point = smp.sympify(input("Enter the y-coordinate: "))
                function_value = float(m.subs({'x':x_point, 'y':y_point}))
                print("The value of the function " + str(m) + " is " + str(function_value) + ".")
            
            response2 = input("Do you want to graph this function? Enter y for 'Yes' and any other key for 'no.': ")
            
            if (response2 == "y"):
                lower_x = smp.sympify(input("Enter the lower x-coordinate: "))
                upper_x = smp.sympify(input("Enter the upper x-coordinate: "))
                lower_y = smp.sympify(input("Enter the lower y-coordinate: "))
                upper_y = smp.sympify(input("Enter the upper y-coordinate: "))
                plot3d(m, (x,lower_x,upper_x),(y,lower_y,upper_y))
                
            response3 = input("Do you want to take a partial derivative? Enter y for 'Yes' and any other key for 'no.': ")
            
            if (response3 == "y"):
                variable = input("Enter the variable (x or y) to differentiate with respect to: ")
                if (variable != "x" and variable != "y"):
                    print("Invalid variable. Please try again.")
                    break
                elif (variable == "x"):
                    partial_x = smp.diff(m,x)
                    print("The partial derivative of " + str(m) + " with respect to x is " + str(partial_x) + ".")
                elif (variable == "y"):
                    partial_y = smp.diff(m,y)
                    print("The partial derivative of " + str(m) + " with respect to y is " + str(partial_y) + ".")
                    
            response4 = input("Do you want to integrate this function? Enter y for 'Yes' and any other key for 'no.': ")
            
            if (response4 == "y"):
                lower_x = smp.sympify(input("Enter the lower x-coordinate: "))
                upper_x = smp.sympify(input("Enter the upper x-coordinate: "))
                lower_y = smp.sympify(input("Enter the lower y-coordinate: "))
                upper_y = smp.sympify(input("Enter the upper y-coordinate: "))
                order = input("Enter the order of integration (dxdy, dydx): ")
                if (order == "dxdy"):
                    integral_value = integrate(m, (x,lower_x,upper_x),(y,lower_y,upper_y))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] is " + str(integral_value) + ".")
                if (order == "dydx"):
                    integral_value = integrate(m, (y,lower_y,upper_y), (x,lower_x,upper_x))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] is " + str(integral_value) + ".")
            
            print("")
            use_again = input("Calculations completed. Would you like to use the calculator again? Enter y for 'Yes' and any other key for 'no.' ")
            if (use_again == "y"):
                print("")
                continue
            else:
                print("")
                print("Thank you for using the calculator!")
                break
                
        elif (variable_num == 3):
            f = input("Please enter a function of (x,y,z) (NOTE: Avoid including other unknown variables in the function. Doing so will cause the program to crash or produce meaningless outputs.): ")
            m = smp.sympify(f)
            response1 = input("Do you want to evaluate this function at a point? Enter y for 'Yes' and any other key for 'no.' ")

            if (response1 == "y"):
                x_point = smp.sympify(input("Enter the x-coordinate: "))
                y_point = smp.sympify(input("Enter the y-coordinate: "))
                z_point = smp.sympify(input("Enter the z-coordinate: "))
                function_value = float(m.subs({'x':x_point, 'y':y_point, 'z':z_point}))
                print("The value of the function " + str(m) + " is " + str(function_value) + ".")
                
            response2 = input("Do you want to take a partial derivative? Enter y for 'Yes' and any other key for 'no.': ")
            
            if (response2 == "y"):
                variable = input("Which variable do you want to differentiate with respect to?")
                if (variable != "x" and variable != "y" and variable != "z"):
                    print("Invalid variable. Please try again.")
                    break
                elif (variable == "x"):
                    partial_x = smp.diff(m,x)
                    print("The partial derivative of " + str(m) + " with respect to x is " + str(partial_x) + ".")
                elif (variable == "y"):
                    partial_y == smp.diff(m,y)
                    print("The partial derivative of " + str(m) + " with respect to y is " + str(partial_y) + ".")
                elif(variable == "z"):
                    partial_z = smp.diff(m,z)
                    print("The partial derivative of " + str(m) + " with respect to z is " + str(partial_z) + ".")
                    
            response3 = input("Do you want to integrate this function? Enter y for 'Yes' and any other key for 'no.': ")
            
            if (response3 == "y"):
                lower_x = smp.sympify(input("Enter the lower x-coordinate: "))
                upper_x = smp.sympify(input("Enter the upper x-coordinate: "))
                lower_y = smp.sympify(input("Enter the lower y-coordinate: "))
                upper_y = smp.sympify(input("Enter the upper y-coordinate: "))
                lower_z = smp.sympify(input("Enter the lower z-coordinate: "))
                upper_z = smp.sympify(input("Enter the upper z-coordinate: "))
                order = input("Enter the order of integration (dxdydz, dxdzdy, dydxdz, dydzdx, dzdxdy, dzdydx): ")
                if (order == "dxdydz"):
                    integral_value = integrate(m, (x, lower_x, upper_x),(y, lower_y, upper_y), (z, lower_z, upper_z))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] x [" + str(lower_z) + "," + str(upper_z) + "] is " + str(integral_value) + ".")
                if (order == "dxdzdy"):
                    integral_value = integrate(m, (x, lower_x, upper_x),(z, lower_z, upper_z), (y, lower_y, upper_y))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] x [" + str(lower_z) + "," + str(upper_z) + "] is " + str(integral_value) + ".")
                if (order == "dydxdz"):
                    integral_value = integrate(m, (y, lower_y, upper_y), (x, lower_x, upper_x),(z, lower_z, upper_z))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] x [" + str(lower_z) + "," + str(upper_z) + "] is " + str(integral_value) + ".")
                if (order == "dydzdx"):
                    integral_value = integrate(m, (y, lower_y, upper_y), (z, lower_z, upper_z), (x, lower_x, upper_x))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] x [" + str(lower_z) + "," + str(upper_z) + "] is " + str(integral_value) + ".")
                if (order == "dzdxdy"):
                    integral_value = integrate(m, (z, lower_z, upper_z), (x, lower_x, upper_x),(y, lower_y, upper_y))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] x [" + str(lower_z) + "," + str(upper_z) + "] is " + str(integral_value) + ".")
                if (order == "dzdydx"):
                    integral_value = integrate(m, (z, lower_z, upper_z), (y, lower_y, upper_y), (x, lower_x, upper_x))
                    print("The value of the integral of " + str(m) + " on " + "[" + str(lower_x) + "," + str(upper_x) + "] x ["  + str(lower_y) + "," + str(upper_y) + "] x [" + str(lower_z) + "," + str(upper_z) + "] is " + str(integral_value) + ".")

            print("")
            use_again = input("Calculations completed. Would you like to use the calculator again? Enter y for 'Yes' and any other key for 'no.' ")
            if (use_again == "y"):
                print("")
                continue
            else:
                print("")
                print("Thank you for using the calculator!")
                break
# Out:
# Welcome to this Python graphing calculator! This program can take in both single and multi-variable (up to 3 variables supported) functions and perform calculus operations on them in addition to graphing them.
#
# Please adhere to this syntax when entering functions:
# Use ** for exponents.
# Use 'pi' to access the constant π.
# Use 'E' (case sensitive) to access the natural number e.
# Use 'oo' to indicate infinity.
# Square root function ---> sqrt(x)
# Nth root function ---> root(x,n)
# sin(x) ---> sin(x)
# cos(x) ---> cos(x)
# tan(x) ---> tan(x)
# csc(x) ---> csc(x)
# sec(x) ---> sec(x)
# cot(x) ---> cot(x)
# sinc(x) ---> sinc(x)
# sin inverse ---> asin(x)
# cos inverse ---> acos(x)
# tan inverse ---> atan(x)
# csc inverse ---> acsc(x)
# sec inverse ---> asec(x)
# cotan inverse ---> acot(x)
# sinh(x) ---> sinh(x)
# cosh(x) ---> cosh(x)
# tanh(x) ---> tanh(x)
# csch(x) ---> csch(x)
# sech(x) ---> sech(x)
# coth(x) ---> coth(x)
# arcsinh(x) ---> asinh(x)
# arccosh(x) ---> acosh(x)
# ...
